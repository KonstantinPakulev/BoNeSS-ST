# %%
from notebooks.__init__ import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
baselines = get_baselines_plot_group('MegaDepth', '43948a4e108e470aaf4468b89ec8df08')

# %% [markdown]
# # Relative pose metrics

# %%
save_dir = Path("/home/konstantin/personal/Summertime/paper/submission/figures/evaluation/megadepth")

accuracy_plotter = RelPoseAccuracyPlotter()

# %%
_ = accuracy_plotter.plot(
    [
        baselines
    ],
)

# %%
# save_figure(accuracy_plotter.plot([baselines], informative=False)[0], save_dir, 'test')

# %%
accuracy_plotter.print_mAA(
    [
        baselines
    ],
    precision=3)
# Out:
# baselines
# 	 SIFT+DISK:
# 	 Rotation: 0.844 mAA Translation: 0.292 mAA
#
# 	 SuperPoint+DISK:
# 	 Rotation: 0.873 mAA Translation: 0.321 mAA
#
# 	 R2D2+DISK:
# 	 Rotation: 0.873 mAA Translation: 0.312 mAA
#
# 	 Key.Net+DISK:
# 	 Rotation: 0.840 mAA Translation: 0.263 mAA
#
# 	 DISK:
# 	 Rotation: 0.883 mAA Translation: 0.321 mAA
#
# 	 REKD+DISK:
# 	 Rotation: 0.855 mAA Translation: 0.274 mAA
#
# 	 Shi-Tomasi+DISK:
# 	 Rotation: 0.863 mAA Translation: 0.307 mAA
#
# 	 NeSS-ST+DISK:
# 	 Rotation: 0.876 mAA Translation: 0.333 mAA
#
# 	 BoNeSS-ST+DISK:
# 	 Rotation: 0.886 mAA Translation: 0.340 mAA

# %%
mean_num_inl_plotter = RelPoseMeanNumInlPlotter()

# %%
mean_num_inl_plotter.plot(
    [
        baselines
    ])

# %%
mean_num_inl_plotter.print(
    [
        baselines
    ])
# Out:
# baselines
# 	 SIFT+DISK:
# 	 Mean number of inliers: 383.6
#
# 	 SuperPoint+DISK:
# 	 Mean number of inliers: 405.5
#
# 	 R2D2+DISK:
# 	 Mean number of inliers: 452.2
#
# 	 Key.Net+DISK:
# 	 Mean number of inliers: 384.6
#
# 	 DISK:
# 	 Mean number of inliers: 622.3
#
# 	 REKD+DISK:
# 	 Mean number of inliers: 394.6
#
# 	 Shi-Tomasi+DISK:
# 	 Mean number of inliers: 429.1
#
# 	 NeSS-ST+DISK:
# 	 Mean number of inliers: 286.8
#
# 	 BoNeSS-ST+DISK:
# 	 Mean number of inliers: 344.7
