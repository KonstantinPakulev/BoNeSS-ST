# %%
from notebooks.__init__ import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
baselines = get_baselines_plot_group('HPatches', '20d101e84155471d8e95fec6f2d5ee46')

# %%
ness_st_beta_ablation = get_ness_st_beta_ablation_plot_group('HPatches')

# %%
boness_st_beta_ablation = get_boness_st_beta_ablation_plot_group('HPatches')

# %% [markdown]
# # Classical metrics

# %%
save_dir = Path("/home/konstantin/personal/Summertime/paper/submission/figures/evaluation/hpatches")

plotter = ClassicalMetricsPlotter()

# %% [markdown]
# ### Repeatability

# %%
figure_list = plotter.plot(
    [
        baselines,
        ness_st_beta_ablation,
        boness_st_beta_ablation
    ],
    metric_name='rep',
)

# %%
# save_figure(plotter.plot([baselines], metric_name='rep', informative=False)[0], save_dir, 'rep')

# %%
plotter.print_metrics(
    [
        baselines,
        ness_st_beta_ablation,
        boness_st_beta_ablation
    ], 
    metric_name='rep', 
    threshold_idx=2)
# Out:
# baselines, Repeatability
# 	 SIFT+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.486
# 		 Illumination: 0.443
# 		 Viewpoint: 0.525
#
# 	 SuperPoint+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.617
# 		 Illumination: 0.576
# 		 Viewpoint: 0.654
#
# 	 R2D2+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.608
# 		 Illumination: 0.567
# 		 Viewpoint: 0.645
#
# 	 Key.Net+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.596
# 		 Illumination: 0.660
# 		 Viewpoint: 0.536
#
# 	 DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.577
# 		 Illumination: 0.584
# 		 Viewpoint: 0.571
#
# 	 REKD+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.542
# 		 Illumination: 0.525
# 		 Viewpoint: 0.558
#
# 	 Shi-Tomasi+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.579
# 		 Illumination: 0.530
# 		 Viewpoint: 0.625
#
# 	 NeSS-ST+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.456
# 		 Illumination: 0.420
# 		 Viewpoint: 0.489
#
# 	 BoNeSS-ST+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.504
# 		 Illumination: 0.482
# 		 Viewpoint: 0.525
#
# ...

# %% [markdown]
# ### MMA

# %%
figure_list = plotter.plot(
    [
        baselines,
        ness_st_beta_ablation,
        boness_st_beta_ablation
    ],
    metric_name='mma',
)

# %%
# save_figure(plotter.plot([baselines], metric_name='mma', informative=False)[0], save_dir, 'mma')

# %%
plotter.print_metrics(
    [
        baselines,
        ness_st_beta_ablation,
        boness_st_beta_ablation
    ], 
    metric_name='mma', 
    threshold_idx=2,
    precision=3)
# Out:
# baselines, MMA
# 	 SIFT+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.740
# 		 Illumination: 0.791
# 		 Viewpoint: 0.693
#
# 	 SuperPoint+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.759
# 		 Illumination: 0.805
# 		 Viewpoint: 0.717
#
# 	 R2D2+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.748
# 		 Illumination: 0.798
# 		 Viewpoint: 0.701
#
# 	 Key.Net+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.685
# 		 Illumination: 0.709
# 		 Viewpoint: 0.662
#
# 	 DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.763
# 		 Illumination: 0.818
# 		 Viewpoint: 0.713
#
# 	 REKD+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.691
# 		 Illumination: 0.770
# 		 Viewpoint: 0.617
#
# 	 Shi-Tomasi+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.772
# 		 Illumination: 0.815
# 		 Viewpoint: 0.731
#
# 	 NeSS-ST+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.702
# 		 Illumination: 0.736
# 		 Viewpoint: 0.670
#
# 	 BoNeSS-ST+DISK
# 	 Pixel threshold: 3.0
# 		 Total: 0.745
# 		 Illumination: 0.795
# 		 Viewpoint: 0.699
#
# ...
