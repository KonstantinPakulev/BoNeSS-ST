# %%
from notebooks.__init__ import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
baselines = get_baselines_plot_group('ScanNet',
                                     'b9b5237102f047528979129edc4d5db7')

# %% [markdown]
# # Relative pose metrics

# %%
save_dir = Path("/home/konstantin/personal/Summertime/paper/submission/figures/evaluation/scannet")

accuracy_plotter = RelPoseAccuracyPlotter()

# %%
figure_list = accuracy_plotter.plot(
    [
        baselines
    ],
)

# %%
# save_figure(accuracy_plotter.plot([baselines], informative=False)[0], save_dir, 'test')

# %%
accuracy_plotter.print_mAA(
    [
        baselines
    ],
    precision=3)
# Out:
# baselines
# 	 SIFT+HardNet:
# 	 Rotation: 0.606 mAA Translation: 0.211 mAA
#
# 	 SuperPoint+HardNet:
# 	 Rotation: 0.643 mAA Translation: 0.234 mAA
#
# 	 R2D2+HardNet:
# 	 Rotation: 0.669 mAA Translation: 0.251 mAA
# 	 Key.Net+HardNet:
# 	 Rotation: 0.588 mAA Translation: 0.206 mAA
#
# 	 DISK:
# 	 Rotation: 0.537 mAA Translation: 0.165 mAA
#
# 	 REKD+HardNet:
# 	 Rotation: 0.657 mAA Translation: 0.241 mAA
#
# 	 Shi-Tomasi+HardNet:
# 	 Rotation: 0.591 mAA Translation: 0.209 mAA
#
# 	 NeSS-ST+HardNet:
# 	 Rotation: 0.633 mAA Translation: 0.225 mAA
#
# 	 BoNeSS-ST+HardNet:
# 	 Rotation: 0.653 mAA Translation: 0.238 mAA

# %%
mean_num_inl_plotter = RelPoseMeanNumInlPlotter()

# %%
mean_num_inl_plotter.plot(
    [
        baselines
    ])

# %%
mean_num_inl_plotter.print(
    [
        baselines
    ])
# Out:
# baselines
# 	 SIFT+HardNet:
# 	 Mean number of inliers: 110.9
#
# 	 SuperPoint+HardNet:
# 	 Mean number of inliers: 107.4
#
# 	 R2D2+HardNet:
# 	 Mean number of inliers: 167.6
#
# 	 Key.Net+HardNet:
# 	 Mean number of inliers: 90.7
#
# 	 DISK:
# 	 Mean number of inliers: 138.4
#
# 	 REKD+HardNet:
# 	 Mean number of inliers: 102.7
#
# 	 Shi-Tomasi+HardNet:
# 	 Mean number of inliers: 149.2
#
# 	 NeSS-ST+HardNet:
# 	 Mean number of inliers: 105.1
#
# 	 BoNeSS-ST+HardNet:
# 	 Mean number of inliers: 154.0
