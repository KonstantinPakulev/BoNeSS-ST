# %%
from notebooks.__init__ import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
baselines = get_baselines_plot_group('HEB', '37e19e14518e4dac855da4415e5ee701')

# %% [markdown]
# # Relative pose metrics

# %%
save_dir = Path("/home/konstantin/personal/Summertime/paper/submission/figures/evaluation/heb")

accuracy_plotter = RelPoseAccuracyPlotter()

# %%
_ = accuracy_plotter.plot(
    [
        baselines
    ]
)

# %%
# save_figure(accuracy_plotter.plot([baselines], informative=False)[0], save_dir, 'test')

# %%
accuracy_plotter.print_mAA(
    [
        baselines
    ])
# Out:
# baselines
# 	 SIFT+DISK:
# 	 Rotation: 0.182 mAA Translation: 0.021 mAA
#
# 	 SuperPoint+DISK:
# 	 Rotation: 0.228 mAA Translation: 0.028 mAA
#
# 	 R2D2+DISK:
# 	 Rotation: 0.232 mAA Translation: 0.029 mAA
#
# 	 Key.Net+DISK:
# 	 Rotation: 0.201 mAA Translation: 0.025 mAA
#
# 	 DISK:
# 	 Rotation: 0.247 mAA Translation: 0.032 mAA
#
# 	 REKD+DISK:
# 	 Rotation: 0.216 mAA Translation: 0.027 mAA
#
# 	 Shi-Tomasi+DISK:
# 	 Rotation: 0.197 mAA Translation: 0.024 mAA
#
# 	 NeSS-ST+DISK:
# 	 Rotation: 0.228 mAA Translation: 0.029 mAA
#
# 	 BoNeSS-ST+DISK:
# 	 Rotation: 0.230 mAA Translation: 0.029 mAA

# %%
mean_num_inl_plotter = RelPoseMeanNumInlPlotter()

# %%
mean_num_inl_plotter.plot(
    [
        baselines
    ])

# %%
mean_num_inl_plotter.print(
    [
        baselines
    ])
# Out:
# baselines
# 	 SIFT+DISK:
# 	 Mean number of inliers: 49.2
#
# 	 SuperPoint+DISK:
# 	 Mean number of inliers: 57.5
#
# 	 R2D2+DISK:
# 	 Mean number of inliers: 66.0
#
# 	 Key.Net+DISK:
# 	 Mean number of inliers: 54.3
#
# 	 DISK:
# 	 Mean number of inliers: 118.8
#
# 	 REKD+DISK:
# 	 Mean number of inliers: 55.1
#
# 	 Shi-Tomasi+DISK:
# 	 Mean number of inliers: 57.0
#
# 	 NeSS-ST+DISK:
# 	 Mean number of inliers: 42.9
#
# 	 BoNeSS-ST+DISK:
# 	 Mean number of inliers: 51.9
